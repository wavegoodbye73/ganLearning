# %% [markdown]
# <a href="https://colab.research.google.com/github/wavegoodbye73/ganLearning/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def crop_centre(img,new_width,new_height):
  height,width,_ = img.shape
  startx = width//2 - new_width//2
  starty = height//2 - new_height//2
  return img[starty:starty + new_height, startx:startx + new_width, :]

# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset

import h5py
import pandas, numpy, random
import matplotlib.pyplot as plt

# %%
class CelebADateset(Dataset):
  def __init__(self,file):
    self.file_object = h5py.File(file,'r')
    self.dataset = self.file_object['img_align_celeba']
    pass

  def __len__(self):
    return len(self.dataset)

  def __getitem__(self,index):
    if (index>=len(self.dataset)):
      raise IndexError()
    img = numpy.array(self.dataset[str(index)+'.jpg'])
    img = crop_centre(img,128,128)
    return torch.cuda.FloatTensor(img).permute(2,0,1).view(1,3,128,128) / 255.0

  def plot_img(self,index):
    img = numpy.array(self.dataset[str(index)+'.jpg'])
    img = crop_centre(img,128,128)
    plt.imshow(img,interpolation='nearest')
    pass

  pass

# %%
from google.colab import drive
drive.mount('./mount')
# Out:
# Mounted at ./mount

# %%
celeba_dataset = CelebADateset('mount/MyDrive/Colab Notebooks/gan/celeba_data/celeba_aligned_small.h5py')

celeba_dataset.plot_img(6)

# %%
class View(nn.Module):
  def __init__(self,shape):
    super().__init__()
    self.shape = shape,

  def forward(self,x):
    return x.view(*self.shape)

# %%
class Dis(nn.Module):
  def __init__(self):
    super().__init__()

    self.model = nn.Sequential(
        nn.Conv2d(3,256,kernel_size = 8, stride = 2),
        nn.BatchNorm2d(256),
        nn.LeakyReLU(0.2),

        nn.Conv2d(256,256,kernel_size = 8, stride = 2),
        nn.BatchNorm2d(256),
        nn.LeakyReLU(0.2),

        nn.Conv2d(256,3,kernel_size=8,stride=2),
        nn.LeakyReLU(0.2),

        View(3*10*10),
        nn.Linear(3*10*10,1),
        nn.Sigmoid()

    )

    self.loss = nn.MSELoss()
    self.optim = torch.optim.Adam(self.parameters(),lr = 0.0001)

    self.counter = 0
    self.progress = []

  def forward(self,input):
    return self.model(input)

  def train(self,input,target):
    output = self.forward(input)
    loss = self.loss(output,target)

    self.counter+=1

    if (self.counter % 10 == 0):
      self.progress.append(loss.item())  
    if (self.counter % 1000 == 0):
      print('counter = ',self.counter)


    self.optim.zero_grad()
    loss.backward()
    self.optim.step()


  def plot_progress(self):
    df = pandas.DataFrame(self.progress, columns=['loss'])
    df.plot(ylim=(0), figsize=(16,8), alpha=0.1, marker='.', grid=True, yticks=(0, 0.25, 0.5, 1.0, 5.0))

# %%
def generate_random_image(size):
  random_data = torch.rand(size)
  return random_data

# %%
D = Dis()

for image_data_tensor in celeba_dataset:
  D.train(image_data_tensor,torch.cuda.FloatTensor([1.0]))
  D.train(generate_random_image((1,3,128,128)), torch.cuda.FloatTensor([0.0]))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-16-0065c93f90ed> in <module>()
#       1 D = Dis()
#       2
# ----> 3 for image_data_tensor in celeba_dataset:
#       4   D.train(image_data_tensor,torch.cuda.FloatTensor([1.0]))
#       5   D.train(generate_random_image((1,3,128,128)), torch.cuda.FloatTensor([0.0]))
#
# <ipython-input-7-7b99aa7b1138> in __getitem__(self, index)
#      13     img = numpy.array(self.dataset[str(index)+'.jpg'])
#      14     img = crop_centre(img,128,128)
# ---> 15     return torch.cuda.FloatTensor(img).permute(2,0,1).view(1,3,128,128) / 255.0
#      16
#      17   def plot_img(self,index):
#
# /usr/local/lib/python3.7/dist-packages/torch/cuda/__init__.py in _lazy_init()
#     214         # This function throws if there's a driver initialization error, no GPUs
#     215         # are found or any other error occurs
# ...
